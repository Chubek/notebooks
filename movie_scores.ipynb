# %%
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import PolynomialFeatures, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.pipeline import Pipeline, make_pipeline
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("/content/tmdb_5000_movies.csv")
data = shuffle(data)
data.head()
data.shape
# Out:
# (4803, 20)

# %%
data.replace([np.inf, -np.inf, np.nan], 0, inplace=True)
data = data.reset_index()

# %%
X_set = data[['vote_average', 'runtime', 'revenue', 'budget']]

# %%
Y_set = data[['popularity']]

# %%
pipeline = make_pipeline(MinMaxScaler(), PolynomialFeatures())

# %%
X_set_scaled = MinMaxScaler().fit_transform(X_set)

# %%
X_set_features_added = PolynomialFeatures(2).fit_transform(X_set_scaled)
