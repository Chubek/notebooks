# %%
import numpy as np
import pandas as pd

# %%
# !pip install nltk rake-nltk
# !python -c "import nltk; nltk.download('stopwords')"
# Out:
# ...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
data = pd.read_csv("/content/tmdb_5000_movies.csv")

# %%
data.head()
# Out:
#       budget  ... vote_count
# 0  237000000  ...      11800
# 1  300000000  ...       4500
# 2  245000000  ...       4466
# 3  250000000  ...       9106
# 4  260000000  ...       2124
#
# [5 rows x 20 columns]

# %%
dataset = np.array([data['title'], data['overview'], data['tagline'], data['vote_count']])

# %%
dataset.shape
# Out:
# (4, 4803)
